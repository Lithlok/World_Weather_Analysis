# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count.
len(cities)
# Out:
# 730

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
          
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":city_desc})
                        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | cherskiy
# Processing Record 4 of Set 1 | ribeira grande
# Processing Record 5 of Set 1 | palmer
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | souillac
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | san ramon
# Processing Record 10 of Set 1 | pangnirtung
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | vostok
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | berezovyy
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | kailua
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | bambous virieux
# Processing Record 19 of Set 1 | fayaoue
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | roswell
# Processing Record 22 of Set 1 | necochea
# Processing Record 23 of Set 1 | ilulissat
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | college
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | hopelchen
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | agadez
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | ancud
# Processing Record 36 of Set 1 | high level
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | saldanha
# Processing Record 39 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | geraldton
# Processing Record 42 of Set 1 | itarema
# Processing Record 43 of Set 1 | lagoa
# Processing Record 44 of Set 1 | iqaluit
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | olinda
# Processing Record 47 of Set 1 | vila velha
# Processing Record 48 of Set 1 | fairbanks
# Processing Record 49 of Set 1 | lebu
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | ugoofaaru
# Processing Record 2 of Set 2 | waddan
# Processing Record 3 of Set 2 | kendari
# Processing Record 4 of Set 2 | saskylakh
# Processing Record 5 of Set 2 | yazykovo
# Processing Record 6 of Set 2 | hounde
# Processing Record 7 of Set 2 | kahului
# Processing Record 8 of Set 2 | balkanabat
# Processing Record 9 of Set 2 | east london
# Processing Record 10 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 2 | mogadishu
# Processing Record 12 of Set 2 | clyde river
# Processing Record 13 of Set 2 | naze
# Processing Record 14 of Set 2 | carnarvon
# Processing Record 15 of Set 2 | ziyang
# Processing Record 16 of Set 2 | veinticinco de mayo
# Processing Record 17 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 2 | general pico
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | duz
# City not found. Skipping...
# Processing Record 21 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 2 | pontes e lacerda
# Processing Record 23 of Set 2 | novikovo
# Processing Record 24 of Set 2 | khani
# Processing Record 25 of Set 2 | kalmunai
# Processing Record 26 of Set 2 | tasiilaq
# Processing Record 27 of Set 2 | bonavista
# Processing Record 28 of Set 2 | busselton
# Processing Record 29 of Set 2 | sobolevo
# Processing Record 30 of Set 2 | tikrit
# Processing Record 31 of Set 2 | slonim
# Processing Record 32 of Set 2 | nanortalik
# Processing Record 33 of Set 2 | dukat
# Processing Record 34 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | castro
# Processing Record 36 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 2 | zhovtneve
# Processing Record 38 of Set 2 | bluff
# Processing Record 39 of Set 2 | kapit
# Processing Record 40 of Set 2 | tapa
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | sinjar
# Processing Record 43 of Set 2 | san francisco del mar
# Processing Record 44 of Set 2 | camacha
# Processing Record 45 of Set 2 | thunder bay
# Processing Record 46 of Set 2 | effingham
# Processing Record 47 of Set 2 | amposta
# Processing Record 48 of Set 2 | arraial do cabo
# Processing Record 49 of Set 2 | mayskiy
# Processing Record 50 of Set 2 | aykhal
# Processing Record 1 of Set 3 | tuktoyaktuk
# Processing Record 2 of Set 3 | dunedin
# Processing Record 3 of Set 3 | koumac
# Processing Record 4 of Set 3 | talnakh
# Processing Record 5 of Set 3 | edessa
# Processing Record 6 of Set 3 | asau
# Processing Record 7 of Set 3 | vestmanna
# Processing Record 8 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 3 | saint petersburg
# Processing Record 10 of Set 3 | faanui
# Processing Record 11 of Set 3 | qaanaaq
# Processing Record 12 of Set 3 | tiksi
# Processing Record 13 of Set 3 | hilo
# Processing Record 14 of Set 3 | bilibino
# Processing Record 15 of Set 3 | matara
# Processing Record 16 of Set 3 | vaini
# Processing Record 17 of Set 3 | anzio
# Processing Record 18 of Set 3 | coquimbo
# Processing Record 19 of Set 3 | hay river
# Processing Record 20 of Set 3 | new norfolk
# Processing Record 21 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 22 of Set 3 | pierre
# Processing Record 23 of Set 3 | san patricio
# Processing Record 24 of Set 3 | toccoa
# Processing Record 25 of Set 3 | kaitangata
# Processing Record 26 of Set 3 | salamiyah
# Processing Record 27 of Set 3 | broome
# Processing Record 28 of Set 3 | nabire
# Processing Record 29 of Set 3 | gamba
# Processing Record 30 of Set 3 | codrington
# Processing Record 31 of Set 3 | haines junction
# Processing Record 32 of Set 3 | chokwe
# Processing Record 33 of Set 3 | riverton
# Processing Record 34 of Set 3 | bengkulu
# Processing Record 35 of Set 3 | tanabi
# Processing Record 36 of Set 3 | touros
# Processing Record 37 of Set 3 | yerbogachen
# Processing Record 38 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 3 | carballo
# Processing Record 40 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 41 of Set 3 | newport
# Processing Record 42 of Set 3 | boden
# Processing Record 43 of Set 3 | qaqortoq
# Processing Record 44 of Set 3 | vila franca do campo
# Processing Record 45 of Set 3 | hofn
# Processing Record 46 of Set 3 | port alfred
# Processing Record 47 of Set 3 | kazachinskoye
# Processing Record 48 of Set 3 | half moon bay
# Processing Record 49 of Set 3 | kavaratti
# Processing Record 50 of Set 3 | cacapava do sul
# Processing Record 1 of Set 4 | ust-nera
# Processing Record 2 of Set 4 | port blair
# Processing Record 3 of Set 4 | mandurah
# Processing Record 4 of Set 4 | gangotri
# City not found. Skipping...
# Processing Record 5 of Set 4 | baba ana
# Processing Record 6 of Set 4 | abu dhabi
# Processing Record 7 of Set 4 | bredasdorp
# Processing Record 8 of Set 4 | taoudenni
# Processing Record 9 of Set 4 | sorong
# Processing Record 10 of Set 4 | khatanga
# Processing Record 11 of Set 4 | oriximina
# Processing Record 12 of Set 4 | makakilo city
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | bandarbeyla
# Processing Record 15 of Set 4 | roma
# Processing Record 16 of Set 4 | dodge city
# Processing Record 17 of Set 4 | acarau
# Processing Record 18 of Set 4 | dubbo
# Processing Record 19 of Set 4 | mahebourg
# Processing Record 20 of Set 4 | sitka
# Processing Record 21 of Set 4 | yulara
# Processing Record 22 of Set 4 | tuatapere
# Processing Record 23 of Set 4 | tiznit
# Processing Record 24 of Set 4 | polgar
# Processing Record 25 of Set 4 | arman
# Processing Record 26 of Set 4 | adrar
# Processing Record 27 of Set 4 | port elizabeth
# Processing Record 28 of Set 4 | isangel
# Processing Record 29 of Set 4 | townsville
# Processing Record 30 of Set 4 | aksarka
# Processing Record 31 of Set 4 | tura
# Processing Record 32 of Set 4 | oum hadjer
# Processing Record 33 of Set 4 | nikolskoye
# Processing Record 34 of Set 4 | sompeta
# Processing Record 35 of Set 4 | san matias
# Processing Record 36 of Set 4 | kavieng
# Processing Record 37 of Set 4 | okha
# Processing Record 38 of Set 4 | mtwara
# Processing Record 39 of Set 4 | srednekolymsk
# Processing Record 40 of Set 4 | luena
# Processing Record 41 of Set 4 | brooks
# Processing Record 42 of Set 4 | victoria point
# Processing Record 43 of Set 4 | burica
# City not found. Skipping...
# Processing Record 44 of Set 4 | newport beach
# Processing Record 45 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 46 of Set 4 | pingliang
# Processing Record 47 of Set 4 | peleduy
# Processing Record 48 of Set 4 | gondanglegi
# Processing Record 49 of Set 4 | sao joao da barra
# Processing Record 50 of Set 4 | jiroft
# City not found. Skipping...
# Processing Record 1 of Set 5 | sivas
# Processing Record 2 of Set 5 | hambantota
# Processing Record 3 of Set 5 | kropotkin
# Processing Record 4 of Set 5 | lazarev
# Processing Record 5 of Set 5 | brae
# Processing Record 6 of Set 5 | tecoanapa
# Processing Record 7 of Set 5 | igarka
# Processing Record 8 of Set 5 | hasaki
# Processing Record 9 of Set 5 | buchanan
# Processing Record 10 of Set 5 | ponta do sol
# Processing Record 11 of Set 5 | santander jimenez
# Processing Record 12 of Set 5 | orotukan
# Processing Record 13 of Set 5 | leningradskiy
# Processing Record 14 of Set 5 | susehri
# Processing Record 15 of Set 5 | jiayuguan
# Processing Record 16 of Set 5 | fare
# Processing Record 17 of Set 5 | karratha
# Processing Record 18 of Set 5 | darhan
# Processing Record 19 of Set 5 | lahat
# Processing Record 20 of Set 5 | chitral
# Processing Record 21 of Set 5 | glotovka
# Processing Record 22 of Set 5 | khulna
# Processing Record 23 of Set 5 | saint george
# Processing Record 24 of Set 5 | batemans bay
# Processing Record 25 of Set 5 | komsomolskiy
# Processing Record 26 of Set 5 | we
# City not found. Skipping...
# Processing Record 27 of Set 5 | yar-sale
# Processing Record 28 of Set 5 | sandakan
# Processing Record 29 of Set 5 | norman wells
# Processing Record 30 of Set 5 | richards bay
# Processing Record 31 of Set 5 | kanpur
# Processing Record 32 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 5 | kawalu
# Processing Record 34 of Set 5 | caruray
# Processing Record 35 of Set 5 | shwebo
# Processing Record 36 of Set 5 | ous
# Processing Record 37 of Set 5 | charters towers
# Processing Record 38 of Set 5 | provideniya
# Processing Record 39 of Set 5 | kihei
# Processing Record 40 of Set 5 | urumqi
# Processing Record 41 of Set 5 | inirida
# Processing Record 42 of Set 5 | aklavik
# Processing Record 43 of Set 5 | mount vernon
# Processing Record 44 of Set 5 | sioux lookout
# Processing Record 45 of Set 5 | ternate
# Processing Record 46 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 5 | isernia
# Processing Record 48 of Set 5 | berlevag
# Processing Record 49 of Set 5 | tarko-sale
# Processing Record 50 of Set 5 | morondava
# Processing Record 1 of Set 6 | airai
# Processing Record 2 of Set 6 | amapa
# Processing Record 3 of Set 6 | haapiti
# Processing Record 4 of Set 6 | torbay
# Processing Record 5 of Set 6 | saint-georges
# Processing Record 6 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 7 of Set 6 | mount isa
# Processing Record 8 of Set 6 | coihaique
# Processing Record 9 of Set 6 | portland
# Processing Record 10 of Set 6 | nova prata
# Processing Record 11 of Set 6 | oksfjord
# Processing Record 12 of Set 6 | moses lake
# Processing Record 13 of Set 6 | mount gambier
# Processing Record 14 of Set 6 | linqiong
# Processing Record 15 of Set 6 | narrabri
# Processing Record 16 of Set 6 | muli
# Processing Record 17 of Set 6 | bilma
# Processing Record 18 of Set 6 | caravelas
# Processing Record 19 of Set 6 | ziro
# Processing Record 20 of Set 6 | lagunas
# Processing Record 21 of Set 6 | kapoeta
# Processing Record 22 of Set 6 | peace river
# Processing Record 23 of Set 6 | biloela
# Processing Record 24 of Set 6 | arlit
# Processing Record 25 of Set 6 | fershampenuaz
# Processing Record 26 of Set 6 | goure
# Processing Record 27 of Set 6 | hazorasp
# Processing Record 28 of Set 6 | poum
# Processing Record 29 of Set 6 | santa fe
# Processing Record 30 of Set 6 | kismayo
# Processing Record 31 of Set 6 | barsovo
# Processing Record 32 of Set 6 | abha
# Processing Record 33 of Set 6 | harper
# Processing Record 34 of Set 6 | vestmannaeyjar
# Processing Record 35 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 36 of Set 6 | codajas
# Processing Record 37 of Set 6 | yamada
# Processing Record 38 of Set 6 | grand island
# Processing Record 39 of Set 6 | bucerias
# Processing Record 40 of Set 6 | arica
# Processing Record 41 of Set 6 | zvishavane
# Processing Record 42 of Set 6 | mahibadhoo
# Processing Record 43 of Set 6 | garowe
# Processing Record 44 of Set 6 | dhamnod
# Processing Record 45 of Set 6 | veraval
# Processing Record 46 of Set 6 | maarianhamina
# Processing Record 47 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 6 | shimoda
# Processing Record 49 of Set 6 | victoria
# Processing Record 50 of Set 6 | thompson
# Processing Record 1 of Set 7 | banda aceh
# Processing Record 2 of Set 7 | cidreira
# Processing Record 3 of Set 7 | shubarshi
# Processing Record 4 of Set 7 | port lincoln
# Processing Record 5 of Set 7 | klaksvik
# Processing Record 6 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 7 | parkent
# Processing Record 8 of Set 7 | ondjiva
# Processing Record 9 of Set 7 | vilhena
# Processing Record 10 of Set 7 | ballina
# Processing Record 11 of Set 7 | kirakira
# Processing Record 12 of Set 7 | fuerte olimpo
# Processing Record 13 of Set 7 | chokurdakh
# Processing Record 14 of Set 7 | bunia
# Processing Record 15 of Set 7 | muros
# Processing Record 16 of Set 7 | ninghai
# Processing Record 17 of Set 7 | husavik
# Processing Record 18 of Set 7 | tallahassee
# Processing Record 19 of Set 7 | vershino-darasunskiy
# Processing Record 20 of Set 7 | altay
# Processing Record 21 of Set 7 | pevek
# Processing Record 22 of Set 7 | buala
# Processing Record 23 of Set 7 | nemuro
# Processing Record 24 of Set 7 | de-kastri
# Processing Record 25 of Set 7 | tahoua
# Processing Record 26 of Set 7 | timra
# Processing Record 27 of Set 7 | thinadhoo
# Processing Record 28 of Set 7 | praia da vitoria
# Processing Record 29 of Set 7 | gizo
# Processing Record 30 of Set 7 | constitucion
# Processing Record 31 of Set 7 | alkhan-kala
# Processing Record 32 of Set 7 | grand gaube
# Processing Record 33 of Set 7 | maun
# Processing Record 34 of Set 7 | crawfordsville
# Processing Record 35 of Set 7 | agva
# City not found. Skipping...
# Processing Record 36 of Set 7 | dikson
# Processing Record 37 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 7 | zhezkazgan
# Processing Record 39 of Set 7 | cervo
# Processing Record 40 of Set 7 | kasongo-lunda
# Processing Record 41 of Set 7 | sur
# Processing Record 42 of Set 7 | male
# Processing Record 43 of Set 7 | sawtell
# Processing Record 44 of Set 7 | bolonchen
# City not found. Skipping...
# Processing Record 45 of Set 7 | meiktila
# Processing Record 46 of Set 7 | longyearbyen
# Processing Record 47 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 7 | rocha
# Processing Record 49 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 7 | nantucket
# Processing Record 1 of Set 8 | mattru
# Processing Record 2 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 8 | los llanos de aridane
# Processing Record 4 of Set 8 | pahrump
# Processing Record 5 of Set 8 | qafsah
# City not found. Skipping...
# Processing Record 6 of Set 8 | sibolga
# Processing Record 7 of Set 8 | hirara
# Processing Record 8 of Set 8 | saint-pierre
# Processing Record 9 of Set 8 | san juan
# Processing Record 10 of Set 8 | tezu
# Processing Record 11 of Set 8 | diffa
# Processing Record 12 of Set 8 | namibe
# Processing Record 13 of Set 8 | rizhao
# Processing Record 14 of Set 8 | baykit
# Processing Record 15 of Set 8 | mehamn
# Processing Record 16 of Set 8 | cap malheureux
# Processing Record 17 of Set 8 | jacobina
# Processing Record 18 of Set 8 | marsa matruh
# Processing Record 19 of Set 8 | upernavik
# Processing Record 20 of Set 8 | havoysund
# Processing Record 21 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 22 of Set 8 | monrovia
# Processing Record 23 of Set 8 | waynesville
# Processing Record 24 of Set 8 | san pedro
# Processing Record 25 of Set 8 | launceston
# Processing Record 26 of Set 8 | teya
# Processing Record 27 of Set 8 | pochutla
# Processing Record 28 of Set 8 | ngunguru
# Processing Record 29 of Set 8 | fartura
# Processing Record 30 of Set 8 | steamboat springs
# Processing Record 31 of Set 8 | norrtalje
# Processing Record 32 of Set 8 | cabo san lucas
# Processing Record 33 of Set 8 | kostomuksha
# Processing Record 34 of Set 8 | esperance
# Processing Record 35 of Set 8 | xingyi
# Processing Record 36 of Set 8 | pacific grove
# Processing Record 37 of Set 8 | mandalgovi
# Processing Record 38 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 8 | livingston
# Processing Record 40 of Set 8 | baboua
# City not found. Skipping...
# Processing Record 41 of Set 8 | slanic-moldova
# Processing Record 42 of Set 8 | marzuq
# Processing Record 43 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 44 of Set 8 | ambilobe
# Processing Record 45 of Set 8 | severo-kurilsk
# Processing Record 46 of Set 8 | henties bay
# Processing Record 47 of Set 8 | prescott valley
# Processing Record 48 of Set 8 | kautokeino
# Processing Record 49 of Set 8 | mingshui
# Processing Record 50 of Set 8 | zhicheng
# Processing Record 1 of Set 9 | turukhansk
# Processing Record 2 of Set 9 | woodinville
# Processing Record 3 of Set 9 | tabuk
# Processing Record 4 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 5 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 9 | muzhi
# Processing Record 7 of Set 9 | hamilton
# Processing Record 8 of Set 9 | port hardy
# Processing Record 9 of Set 9 | hovd
# Processing Record 10 of Set 9 | yenagoa
# Processing Record 11 of Set 9 | noumea
# Processing Record 12 of Set 9 | buraydah
# Processing Record 13 of Set 9 | killybegs
# Processing Record 14 of Set 9 | narimanov
# Processing Record 15 of Set 9 | vagay
# Processing Record 16 of Set 9 | taksimo
# Processing Record 17 of Set 9 | jiancheng
# Processing Record 18 of Set 9 | axim
# Processing Record 19 of Set 9 | aksu
# Processing Record 20 of Set 9 | vanimo
# Processing Record 21 of Set 9 | krasnoarmeyskoye
# Processing Record 22 of Set 9 | luderitz
# Processing Record 23 of Set 9 | pathein
# Processing Record 24 of Set 9 | lanzhou
# Processing Record 25 of Set 9 | keetmanshoop
# Processing Record 26 of Set 9 | rovaniemi
# Processing Record 27 of Set 9 | awjilah
# Processing Record 28 of Set 9 | cayenne
# Processing Record 29 of Set 9 | kruisfontein
# Processing Record 30 of Set 9 | cukai
# Processing Record 31 of Set 9 | trairi
# Processing Record 32 of Set 9 | beloha
# Processing Record 33 of Set 9 | sao filipe
# Processing Record 34 of Set 9 | taybad
# Processing Record 35 of Set 9 | butte
# Processing Record 36 of Set 9 | magadi
# Processing Record 37 of Set 9 | iberia
# Processing Record 38 of Set 9 | mirina
# City not found. Skipping...
# Processing Record 39 of Set 9 | venice
# Processing Record 40 of Set 9 | linkoping
# Processing Record 41 of Set 9 | suwannaphum
# Processing Record 42 of Set 9 | mendoza
# Processing Record 43 of Set 9 | westport
# Processing Record 44 of Set 9 | aleksandrov gay
# Processing Record 45 of Set 9 | noyabrsk
# Processing Record 46 of Set 9 | destin
# Processing Record 47 of Set 9 | bousse
# Processing Record 48 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 9 | thaton
# Processing Record 50 of Set 9 | alofi
# Processing Record 1 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 2 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 3 of Set 10 | lincoln
# Processing Record 4 of Set 10 | krasnoselkup
# Processing Record 5 of Set 10 | rincon
# Processing Record 6 of Set 10 | chuy
# Processing Record 7 of Set 10 | kalat
# Processing Record 8 of Set 10 | riberalta
# Processing Record 9 of Set 10 | cap-aux-meules
# Processing Record 10 of Set 10 | lusambo
# Processing Record 11 of Set 10 | linxia
# Processing Record 12 of Set 10 | roald
# Processing Record 13 of Set 10 | boa vista
# Processing Record 14 of Set 10 | tevaitoa
# Processing Record 15 of Set 10 | merrill
# Processing Record 16 of Set 10 | silvan
# Processing Record 17 of Set 10 | fonte boa
# Processing Record 18 of Set 10 | hun
# Processing Record 19 of Set 10 | soure
# Processing Record 20 of Set 10 | contai
# Processing Record 21 of Set 10 | san cristobal
# Processing Record 22 of Set 10 | lonavale
# Processing Record 23 of Set 10 | bani walid
# Processing Record 24 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 25 of Set 10 | faya
# Processing Record 26 of Set 10 | khorramshahr
# Processing Record 27 of Set 10 | palm coast
# Processing Record 28 of Set 10 | okhotsk
# Processing Record 29 of Set 10 | ibanda
# Processing Record 30 of Set 10 | verkhoyansk
# Processing Record 31 of Set 10 | bathsheba
# Processing Record 32 of Set 10 | comodoro rivadavia
# Processing Record 33 of Set 10 | nuuk
# Processing Record 34 of Set 10 | tanah merah
# Processing Record 35 of Set 10 | nueva loja
# Processing Record 36 of Set 10 | sao miguel do araguaia
# Processing Record 37 of Set 10 | manakara
# Processing Record 38 of Set 10 | lewiston
# Processing Record 39 of Set 10 | derzhavinsk
# Processing Record 40 of Set 10 | paramonga
# Processing Record 41 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 10 | hervey bay
# Processing Record 43 of Set 10 | prince george
# Processing Record 44 of Set 10 | colares
# Processing Record 45 of Set 10 | saint-francois
# Processing Record 46 of Set 10 | jutai
# Processing Record 47 of Set 10 | pitimbu
# Processing Record 48 of Set 10 | kemijarvi
# Processing Record 49 of Set 10 | amazar
# Processing Record 50 of Set 10 | neiafu
# Processing Record 1 of Set 11 | rawson
# Processing Record 2 of Set 11 | omaha
# Processing Record 3 of Set 11 | umm lajj
# Processing Record 4 of Set 11 | anadyr
# Processing Record 5 of Set 11 | bima
# Processing Record 6 of Set 11 | arvika
# Processing Record 7 of Set 11 | honghu
# Processing Record 8 of Set 11 | beringovskiy
# Processing Record 9 of Set 11 | can
# Processing Record 10 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 11 of Set 11 | savalou
# Processing Record 12 of Set 11 | ust-kulom
# Processing Record 13 of Set 11 | marawi
# Processing Record 14 of Set 11 | tomatlan
# Processing Record 15 of Set 11 | puerto escondido
# Processing Record 16 of Set 11 | pisco
# Processing Record 17 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 11 | lopandino
# Processing Record 19 of Set 11 | oranjemund
# Processing Record 20 of Set 11 | ahipara
# Processing Record 21 of Set 11 | bubaque
# Processing Record 22 of Set 11 | pachino
# Processing Record 23 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 24 of Set 11 | atsiki
# City not found. Skipping...
# Processing Record 25 of Set 11 | acapulco
# Processing Record 26 of Set 11 | bam
# Processing Record 27 of Set 11 | pokhara
# Processing Record 28 of Set 11 | koboko
# Processing Record 29 of Set 11 | hryshkivtsi
# Processing Record 30 of Set 11 | maungaturoto
# Processing Record 31 of Set 11 | tongren
# Processing Record 32 of Set 11 | zhangye
# Processing Record 33 of Set 11 | huadian
# Processing Record 34 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 35 of Set 11 | madimba
# Processing Record 36 of Set 11 | atar
# Processing Record 37 of Set 11 | benguela
# Processing Record 38 of Set 11 | palasa
# Processing Record 39 of Set 11 | honningsvag
# Processing Record 40 of Set 11 | olafsvik
# Processing Record 41 of Set 11 | alappuzha
# Processing Record 42 of Set 11 | cockburn town
# Processing Record 43 of Set 11 | kollam
# Processing Record 44 of Set 11 | tingo maria
# Processing Record 45 of Set 11 | dubovskoye
# Processing Record 46 of Set 11 | senneterre
# Processing Record 47 of Set 11 | pryazha
# Processing Record 48 of Set 11 | mindelo
# Processing Record 49 of Set 11 | haikou
# Processing Record 50 of Set 11 | vanavara
# Processing Record 1 of Set 12 | kiunga
# Processing Record 2 of Set 12 | ostrovnoy
# Processing Record 3 of Set 12 | rivadavia
# Processing Record 4 of Set 12 | gigmoto
# Processing Record 5 of Set 12 | flin flon
# Processing Record 6 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 12 | puerto gaitan
# Processing Record 9 of Set 12 | salinopolis
# Processing Record 10 of Set 12 | lompoc
# Processing Record 11 of Set 12 | carazinho
# Processing Record 12 of Set 12 | puurmani
# Processing Record 13 of Set 12 | jinchang
# Processing Record 14 of Set 12 | shelburne
# Processing Record 15 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 12 | pangkalanbuun
# Processing Record 17 of Set 12 | honiara
# Processing Record 18 of Set 12 | chor
# Processing Record 19 of Set 12 | yashkul
# Processing Record 20 of Set 12 | shache
# Processing Record 21 of Set 12 | staritsa
# Processing Record 22 of Set 12 | nortelandia
# Processing Record 23 of Set 12 | turek
# Processing Record 24 of Set 12 | placerville
# Processing Record 25 of Set 12 | yeppoon
# Processing Record 26 of Set 12 | gawler
# Processing Record 27 of Set 12 | pasir gudang
# Processing Record 28 of Set 12 | skarzysko-kamienna
# Processing Record 29 of Set 12 | samoded
# Processing Record 30 of Set 12 | kantilo
# Processing Record 31 of Set 12 | katsuura
# Processing Record 32 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 33 of Set 12 | te anau
# Processing Record 34 of Set 12 | kapasan
# Processing Record 35 of Set 12 | dromolaxia
# Processing Record 36 of Set 12 | usinsk
# Processing Record 37 of Set 12 | alugan
# Processing Record 38 of Set 12 | forio
# Processing Record 39 of Set 12 | bac lieu
# Processing Record 40 of Set 12 | ponta delgada
# Processing Record 41 of Set 12 | douentza
# Processing Record 42 of Set 12 | vzmorye
# Processing Record 43 of Set 12 | kakamega
# Processing Record 44 of Set 12 | tateyama
# Processing Record 45 of Set 12 | hurricane
# Processing Record 46 of Set 12 | puerto varas
# Processing Record 47 of Set 12 | guerrero negro
# Processing Record 48 of Set 12 | hanmer springs
# Processing Record 49 of Set 12 | merritt island
# Processing Record 50 of Set 12 | port moresby
# Processing Record 1 of Set 13 | mucurapo
# Processing Record 2 of Set 13 | olenino
# Processing Record 3 of Set 13 | manggar
# Processing Record 4 of Set 13 | anito
# Processing Record 5 of Set 13 | pomabamba
# Processing Record 6 of Set 13 | sao felix do xingu
# Processing Record 7 of Set 13 | angoche
# Processing Record 8 of Set 13 | baker city
# Processing Record 9 of Set 13 | luocheng
# Processing Record 10 of Set 13 | igbo ora
# Processing Record 11 of Set 13 | tolaga bay
# Processing Record 12 of Set 13 | mikkeli
# Processing Record 13 of Set 13 | aswan
# Processing Record 14 of Set 13 | kenai
# Processing Record 15 of Set 13 | fortuna
# Processing Record 16 of Set 13 | nakamura
# Processing Record 17 of Set 13 | belyy yar
# Processing Record 18 of Set 13 | saint-augustin
# Processing Record 19 of Set 13 | lasa
# Processing Record 20 of Set 13 | iquitos
# Processing Record 21 of Set 13 | salalah
# Processing Record 22 of Set 13 | flinders
# Processing Record 23 of Set 13 | hami
# Processing Record 24 of Set 13 | kuito
# Processing Record 25 of Set 13 | la paz
# Processing Record 26 of Set 13 | sistranda
# Processing Record 27 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 13 | terrace
# Processing Record 29 of Set 13 | nome
# Processing Record 30 of Set 13 | padang
# Processing Record 31 of Set 13 | lerwick
# Processing Record 32 of Set 13 | yuzhne
# Processing Record 33 of Set 13 | catio
# Processing Record 34 of Set 13 | tabas
# Processing Record 35 of Set 13 | eskisehir
# Processing Record 36 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 37 of Set 13 | utica
# Processing Record 38 of Set 13 | tawang
# Processing Record 39 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 40 of Set 13 | menongue
# Processing Record 41 of Set 13 | madingou
# Processing Record 42 of Set 13 | lebanon
# Processing Record 43 of Set 13 | dingle
# Processing Record 44 of Set 13 | chongwe
# Processing Record 45 of Set 13 | hualmay
# Processing Record 46 of Set 13 | bolshaya martynovka
# Processing Record 47 of Set 13 | gold coast
# Processing Record 48 of Set 13 | viedma
# Processing Record 49 of Set 13 | huron
# Processing Record 50 of Set 13 | rodrigues alves
# Processing Record 1 of Set 14 | swan river
# Processing Record 2 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 14 | kudahuvadhoo
# Processing Record 4 of Set 14 | firminopolis
# Processing Record 5 of Set 14 | lichinga
# Processing Record 6 of Set 14 | pokrovsk
# Processing Record 7 of Set 14 | malazgirt
# Processing Record 8 of Set 14 | lethem
# Processing Record 9 of Set 14 | margate
# Processing Record 10 of Set 14 | ghatanji
# Processing Record 11 of Set 14 | emerald
# Processing Record 12 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 13 of Set 14 | shingu
# Processing Record 14 of Set 14 | yaan
# Processing Record 15 of Set 14 | port-gentil
# Processing Record 16 of Set 14 | bonthe
# Processing Record 17 of Set 14 | tucuman
# Processing Record 18 of Set 14 | rio gallegos
# Processing Record 19 of Set 14 | ivanovka
# Processing Record 20 of Set 14 | kloulklubed
# Processing Record 21 of Set 14 | shibetsu
# Processing Record 22 of Set 14 | gasa
# Processing Record 23 of Set 14 | lavrentiya
# Processing Record 24 of Set 14 | misratah
# Processing Record 25 of Set 14 | dourbali
# Processing Record 26 of Set 14 | ensley
# Processing Record 27 of Set 14 | parkes
# Processing Record 28 of Set 14 | paamiut
# Processing Record 29 of Set 14 | tadine
# Processing Record 30 of Set 14 | coahuayana
# Processing Record 31 of Set 14 | zakharo
# City not found. Skipping...
# Processing Record 32 of Set 14 | mahaicony
# City not found. Skipping...
# Processing Record 33 of Set 14 | yumen
# Processing Record 34 of Set 14 | hevizgyork
# City not found. Skipping...
# Processing Record 35 of Set 14 | isla mujeres
# Processing Record 36 of Set 14 | rio grande
# Processing Record 37 of Set 14 | uhlove
# Processing Record 38 of Set 14 | kamuli
# Processing Record 39 of Set 14 | huangpu
# Processing Record 40 of Set 14 | eureka
# Processing Record 41 of Set 14 | weatherford
# Processing Record 42 of Set 14 | miles city
# Processing Record 43 of Set 14 | mareeba
# Processing Record 44 of Set 14 | arrifes
# Processing Record 45 of Set 14 | saint-leu
# Processing Record 46 of Set 14 | hobyo
# Processing Record 47 of Set 14 | atbasar
# Processing Record 48 of Set 14 | nathdwara
# Processing Record 49 of Set 14 | pimentel
# Processing Record 50 of Set 14 | tambopata
# Processing Record 1 of Set 15 | barra do garcas
# Processing Record 2 of Set 15 | amet
# Processing Record 3 of Set 15 | leh
# Processing Record 4 of Set 15 | waipawa
# Processing Record 5 of Set 15 | vitim
# Processing Record 6 of Set 15 | bulgan
# Processing Record 7 of Set 15 | yebaishou
# Processing Record 8 of Set 15 | perth
# Processing Record 9 of Set 15 | kyzyl-suu
# Processing Record 10 of Set 15 | saint-joseph
# Processing Record 11 of Set 15 | masyaf
# Processing Record 12 of Set 15 | chilca
# Processing Record 13 of Set 15 | perelyub
# Processing Record 14 of Set 15 | bom jesus
# Processing Record 15 of Set 15 | tagusao
# Processing Record 16 of Set 15 | nelson bay
# Processing Record 17 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 18 of Set 15 | saint anthony
# Processing Record 19 of Set 15 | manzil jamil
# City not found. Skipping...
# Processing Record 20 of Set 15 | grindavik
# Processing Record 21 of Set 15 | goderich
# Processing Record 22 of Set 15 | kharitonovo
# Processing Record 23 of Set 15 | eydhafushi
# Processing Record 24 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 15 | boguchany
# Processing Record 26 of Set 15 | ust-kut
# Processing Record 27 of Set 15 | varkaus
# Processing Record 28 of Set 15 | were ilu
# Processing Record 29 of Set 15 | tazovskiy
# Processing Record 30 of Set 15 | pavlodar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 668

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mataura -46.1927  168.8643     40.48        90          99
# 1      Butaritari   3.0707  172.7902     83.59        71           0
# 2        Cherskiy  68.7500  161.3000     38.55        86          63
# 3  Ribeira Grande  38.5167  -28.7000     75.60        78          40
# 4          Palmer  42.1584  -72.3287     72.01        85          20
# 5          Barrow  71.2906 -156.7887     37.42        93          90
# 6        Souillac -20.5167   57.5167     75.58        60          40
# 7           Kapaa  22.0752 -159.3190     79.12        83          90
# 8       San Ramon  37.7799 -121.9780     60.82        84           1
# 9     Pangnirtung  66.1451  -65.7125     46.40        71          90
#
#    Wind Speed Country                 Date Current Description
# 0        3.69      NZ  2021-07-24 12:40:05     overcast clouds
# 1       16.89      KI  2021-07-24 12:37:52           clear sky
# 2        6.67      RU  2021-07-24 12:40:05       broken clouds
# 3       19.57      PT  2021-07-24 12:36:12    scattered clouds
# 4        0.00      US  2021-07-24 12:40:06          few clouds
# 5        8.05      US  2021-07-24 12:40:06          light rain
# 6        8.05      MU  2021-07-24 12:40:06    scattered clouds
# 7        4.00      US  2021-07-24 12:40:07          light rain
# 8        0.00      US  2021-07-24 12:39:57           clear sky
# 9        5.75      CA  2021-07-24 12:40:07     overcast clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mataura      NZ -46.1927  168.8643     40.48        90          99
# 1      Butaritari      KI   3.0707  172.7902     83.59        71           0
# 2        Cherskiy      RU  68.7500  161.3000     38.55        86          63
# 3  Ribeira Grande      PT  38.5167  -28.7000     75.60        78          40
# 4          Palmer      US  42.1584  -72.3287     72.01        85          20
# 5          Barrow      US  71.2906 -156.7887     37.42        93          90
# 6        Souillac      MU -20.5167   57.5167     75.58        60          40
# 7           Kapaa      US  22.0752 -159.3190     79.12        83          90
# 8       San Ramon      US  37.7799 -121.9780     60.82        84           1
# 9     Pangnirtung      CA  66.1451  -65.7125     46.40        71          90
#
#    Wind Speed Current Description
# 0        3.69     overcast clouds
# 1       16.89           clear sky
# 2        6.67       broken clouds
# 3       19.57    scattered clouds
# 4        0.00          few clouds
# 5        8.05          light rain
# 6        8.05    scattered clouds
# 7        4.00          light rain
# 8        0.00           clear sky
# 9        5.75     overcast clouds

# %%
city_data_df.to_csv('WeatherPy_Database.csv', index = False)
